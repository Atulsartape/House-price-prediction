# %%
import pandas as pd 
df = pd.read_csv(r"Housing.csv")
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  ... hotwaterheating airconditioning parking prefarea furnishingstatus
# 0  13300000  7420         4          2        3  ...              no             yes       2      yes        furnished
# 1  12250000  8960         4          4        4  ...              no             yes       3       no        furnished
# 2  12250000  9960         3          2        2  ...              no              no       2      yes   semi-furnished
# 3  12215000  7500         4          2        2  ...              no             yes       3      yes        furnished
# 4  11410000  7420         4          1        2  ...              no             yes       2       no        furnished
#
# [5 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories     parking
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505    0.693578
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492    0.861586
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000    0.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000    0.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000    0.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000    1.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000    3.000000

# %%
df['area'].describe()
# Out:
# count      545.000000
# mean      5150.541284
# std       2170.141023
# min       1650.000000
# 25%       3600.000000
# 50%       4600.000000
# 75%       6360.000000
# max      16200.000000
# Name: area, dtype: float64

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
plt.hist(df['area'],bins=20,rwidth=0.8)
# Out:
# (array([ 20.,  53., 105.,  93.,  47.,  70.,  56.,  32.,  23.,  16.,   8.,
#           7.,   4.,   4.,   1.,   4.,   0.,   0.,   0.,   2.]),
#  array([ 1650. ,  2377.5,  3105. ,  3832.5,  4560. ,  5287.5,  6015. ,
#          6742.5,  7470. ,  8197.5,  8925. ,  9652.5, 10380. , 11107.5,
#         11835. , 12562.5, 13290. , 14017.5, 14745. , 15472.5, 16200. ]),
#  <BarContainer object of 20 artists>)

# %%
Q1,Q3 , IQR = Q3-Q1 , lower_limit = Q1-1.5IQR , upperlimit Q3+1.5IQR

# %%
Q1 = df['area'].quantile(0.25)
Q3 = df['area'].quantile(0.75)
Q1,Q3
# Out:
# (np.float64(3600.0), np.float64(6360.0))

# %%
IQR = Q3-Q1

# %%
lower_limit = Q1-1.5*IQR
upper_limit = Q3+1.5*IQR
lower_limit,upper_limit
# Out:
# (np.float64(-540.0), np.float64(10500.0))

# %%
df1 = df[(df['area']<upper_limit) & (df['area']>lower_limit)]

# %%
df1
# Out:
#         price  area  bedrooms  bathrooms  stories  ... hotwaterheating airconditioning parking prefarea furnishingstatus
# 0    13300000  7420         4          2        3  ...              no             yes       2      yes        furnished
# 1    12250000  8960         4          4        4  ...              no             yes       3       no        furnished
# 2    12250000  9960         3          2        2  ...              no              no       2      yes   semi-furnished
# 3    12215000  7500         4          2        2  ...              no             yes       3      yes        furnished
# 4    11410000  7420         4          1        2  ...              no             yes       2       no        furnished
# ..        ...   ...       ...        ...      ...  ...             ...             ...     ...      ...              ...
# 540   1820000  3000         2          1        1  ...              no              no       2       no      unfurnished
# ...

# %%
df.shape
# Out:
# (545, 13)

# %%
df1.shape
# Out:
# (530, 13)

# %%
plt.hist(df1.area,bins=20,rwidth=0.8)
# Out:
# (array([ 8., 19., 23., 51., 77., 58., 44., 33., 29., 46., 28., 35., 17.,
#         17., 14., 12.,  9.,  1.,  5.,  4.]),
#  array([ 1650. ,  2085.5,  2521. ,  2956.5,  3392. ,  3827.5,  4263. ,
#          4698.5,  5134. ,  5569.5,  6005. ,  6440.5,  6876. ,  7311.5,
#          7747. ,  8182.5,  8618. ,  9053.5,  9489. ,  9924.5, 10360. ]),
#  <BarContainer object of 20 artists>)

# %%
df1.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  ... hotwaterheating airconditioning parking prefarea furnishingstatus
# 0  13300000  7420         4          2        3  ...              no             yes       2      yes        furnished
# 1  12250000  8960         4          4        4  ...              no             yes       3       no        furnished
# 2  12250000  9960         3          2        2  ...              no              no       2      yes   semi-furnished
# 3  12215000  7500         4          2        2  ...              no             yes       3      yes        furnished
# 4  11410000  7420         4          1        2  ...              no             yes       2       no        furnished
#
# [5 rows x 13 columns]

# %%
df1.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df1['main_road'] = pd.get_dummies(df1.mainroad,drop_first=True,dtype=int)


df1['gues_troom'] = pd.get_dummies(df1.guestroom,drop_first=True,dtype=int)
df1['base_ment'] = pd.get_dummies(df1.basement,drop_first=True,dtype=int)
df1['air_conditioning'] = pd.get_dummies(df1.airconditioning,drop_first=True,dtype=int)
df1['pref_area'] = pd.get_dummies(df1.prefarea,drop_first=True,dtype=int)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16336\2416954624.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['main_road'] = pd.get_dummies(df1.mainroad,drop_first=True,dtype=int)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16336\2416954624.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['hot_waterheating'] = pd.get_dummies(df1.hotwaterheating,drop_first=True,dtype=int)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16336\2416954624.py:3: SettingWithCopyWarning:
# ...

# %%
df1['hot_waterheating'] = pd.get_dummies(df1.hotwaterheating,drop_first=True,dtype=int)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16336\242263800.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['hot_waterheating'] = pd.get_dummies(df1.hotwaterheating,drop_first=True,dtype=int)

# %%
df1['hot_waterheating'] = pd.get_dummies(df1.hotwaterheating,drop_first=True,dtype=int)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16336\242263800.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['hot_waterheating'] = pd.get_dummies(df1.hotwaterheating,drop_first=True,dtype=int)

# %%
df1.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  ... hot_waterheating gues_troom base_ment air_conditioning pref_area
# 0  13300000  7420         4          2        3  ...                0          0         0                1         1
# 1  12250000  8960         4          4        4  ...                0          0         0                1         0
# 2  12250000  9960         3          2        2  ...                0          0         1                0         1
# 3  12215000  7500         4          2        2  ...                0          0         1                1         1
# 4  11410000  7420         4          1        2  ...                0          1         1                1         0
#
# [5 rows x 19 columns]

# %%
df1.drop(['guestroom','basement','hotwaterheating','airconditioning','prefarea'],axis='columns',inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16336\2273810647.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(['guestroom','basement','hotwaterheating','airconditioning','prefarea'],axis='columns',inplace=True)

# %%
df1.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  ... hot_waterheating  gues_troom base_ment  air_conditioning  pref_area
# 0  13300000  7420         4          2        3  ...                0           0         0                 1          1
# 1  12250000  8960         4          4        4  ...                0           0         0                 1          0
# 2  12250000  9960         3          2        2  ...                0           0         1                 0          1
# 3  12215000  7500         4          2        2  ...                0           0         1                 1          1
# 4  11410000  7420         4          1        2  ...                0           1         1                 1          0
#
# [5 rows x 14 columns]

# %%
df1.drop('mainroad',axis='columns',inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16336\644383601.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop('mainroad',axis='columns',inplace=True)

# %%
df1.head(2)
# Out:
#       price  area  bedrooms  bathrooms  stories  ...  hot_waterheating gues_troom  base_ment  air_conditioning  pref_area
# 0  13300000  7420         4          2        3  ...                 0          0          0                 1          1
# 1  12250000  8960         4          4        4  ...                 0          0          0                 1          0
#
# [2 rows x 13 columns]

# %%
def chk(x):
    if x == 'furnished':
        return 1
    elif x == 'semi-furnished':
        return 2
    else : 
         return 3
df1['Furnish'] = df1['furnishingstatus'].apply(chk)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16336\2929743634.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Furnish'] = df1['furnishingstatus'].apply(chk)

# %%
df1.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  ...  gues_troom base_ment  air_conditioning  pref_area  Furnish
# 0  13300000  7420         4          2        3  ...           0         0                 1          1        1
# 1  12250000  8960         4          4        4  ...           0         0                 1          0        1
# 2  12250000  9960         3          2        2  ...           0         1                 0          1        2
# 3  12215000  7500         4          2        2  ...           0         1                 1          1        1
# 4  11410000  7420         4          1        2  ...           1         1                 1          0        1
#
# [5 rows x 14 columns]

# %%
df1.drop('furnishingstatus',axis='columns',inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16336\1785119847.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop('furnishingstatus',axis='columns',inplace=True)

# %%
df1.head(2)
# Out:
#       price  area  bedrooms  bathrooms  stories  ...  gues_troom  base_ment  air_conditioning  pref_area  Furnish
# 0  13300000  7420         4          2        3  ...           0          0                 1          1        1
# 1  12250000  8960         4          4        4  ...           0          0                 1          0        1
#
# [2 rows x 13 columns]

# %%
X.head()
# Out:
#    area  bedrooms  bathrooms  stories  parking  ...  gues_troom  base_ment  air_conditioning  pref_area  Furnish
# 0  7420         4          2        3        2  ...           0          0                 1          1        1
# 1  8960         4          4        4        3  ...           0          0                 1          0        1
# 2  9960         3          2        2        2  ...           0          1                 0          1        2
# 3  7500         4          2        2        3  ...           0          1                 1          1        1
# 4  7420         4          1        2        2  ...           1          1                 1          0        1
#
# [5 rows x 12 columns]

# %%
y.head()
# Out:
# 0    13300000
# 1    12250000
# 2    12250000
# 3    12215000
# 4    11410000
# Name: price, dtype: int64

# %%
df1['price_per_sqrft'] = df1['price'] / df1['area']
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16336\1230692532.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['price_per_sqrft'] = df1['price'] / df1['area']

# %%
df1.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  ...  base_ment  air_conditioning  pref_area  Furnish  price_per_sqrft
# 0  13300000  7420         4          2        3  ...          0                 1          1        1      1792.452830
# 1  12250000  8960         4          4        4  ...          0                 1          0        1      1367.187500
# 2  12250000  9960         3          2        2  ...          1                 0          1        2      1229.919679
# 3  12215000  7500         4          2        2  ...          1                 1          1        1      1628.666667
# 4  11410000  7420         4          1        2  ...          1                 1          0        1      1537.735849
#
# [5 rows x 14 columns]

# %%
df1['price_per_sqrft'].describe()
# Out:
# count     530.000000
# mean     1006.566260
# std       341.637484
# min       318.181818
# 25%       765.583554
# 50%       962.058081
# 75%      1187.987329
# max      2640.000000
# Name: price_per_sqrft, dtype: float64

# %%
plt.hist(df1.price_per_sqrft,bins=20,rwidth=0.8)
# Out:
# (array([ 8., 29., 38., 62., 81., 79., 71., 63., 27., 17., 13., 21.,  9.,
#          6.,  4.,  0.,  1.,  0.,  0.,  1.]),
#  array([ 318.18181818,  434.27272727,  550.36363636,  666.45454545,
#          782.54545455,  898.63636364, 1014.72727273, 1130.81818182,
#         1246.90909091, 1363.        , 1479.09090909, 1595.18181818,
#         1711.27272727, 1827.36363636, 1943.45454545, 2059.54545455,
#         2175.63636364, 2291.72727273, 2407.81818182, 2523.90909091,
#         2640.        ]),
#  <BarContainer object of 20 artists>)

# %%
new_Q1 = df1['price_per_sqrft'].quantile(0.25)
new_Q3 = df1['price_per_sqrft'].quantile(0.75)

# %%
new_IQR = new_Q3-new_Q1

# %%
low = new_Q1 - 1.5*new_IQR
up = new_Q3 + 1.5*new_IQR

# %%
df2 = df1[(df1['price_per_sqrft'] > low) & (df1['price_per_sqrft'] < up)]

# %%
df2.head(2)
# Out:
#      price  area  bedrooms  bathrooms  stories  ...  base_ment  air_conditioning  pref_area  Furnish  price_per_sqrft
# 0  8855000  6420         3          2        2  ...          0                 1          1        2      1379.283489
# 1  8680000  7155         3          2        1  ...          1                 1          0        3      1213.137666
#
# [2 rows x 14 columns]

# %%
df2 = df2.drop(df2.index[:10]).reset_index(drop=True)
df2 = df2.iloc[:-10].reset_index(drop=True)

# %%
df2.head(2)
# Out:
#      price  area  bedrooms  bathrooms  stories  ...  base_ment  air_conditioning  pref_area  Furnish  price_per_sqrft
# 0  8400000  7000         3          1        4  ...          0                 1          0        2      1200.000000
# 1  8295000  4880         4          2        2  ...          0                 1          1        1      1699.795082
#
# [2 rows x 14 columns]

# %%
plt.hist(df2['price_per_sqrft'],bins=20,rwidth=0.8)
# Out:
# (array([ 5.,  9., 14., 21., 34., 41., 44., 57., 47., 47., 43., 39., 25.,
#         17., 13.,  1., 10., 13.,  6.,  7.]),
#  array([ 318.18181818,  392.59530792,  467.00879765,  541.42228739,
#          615.83577713,  690.24926686,  764.6627566 ,  839.07624633,
#          913.48973607,  987.90322581, 1062.31671554, 1136.73020528,
#         1211.14369501, 1285.55718475, 1359.97067449, 1434.38416422,
#         1508.79765396, 1583.2111437 , 1657.62463343, 1732.03812317,
#         1806.4516129 ]),
#  <BarContainer object of 20 artists>)

# %%
X = df2.drop(['price','price_per_sqrft'],axis='columns')
y = df2.price_per_sqrft

# %%
X.head(2)
# Out:
#    area  bedrooms  bathrooms  stories  parking  ...  gues_troom  base_ment  air_conditioning  pref_area  Furnish
# 0  6420         3          2        2        1  ...           0          0                 1          1        2
# 1  7155         3          2        1        2  ...           1          1                 1          0        3
#
# [2 rows x 12 columns]

# %%
y.head()
# Out:
# 0    1379.283489
# 1    1213.137666
# 2    1073.913043
# 3     974.431818
# 4    1305.810398
# Name: price_per_sqrft, dtype: float64

# %%
from sklearn.model_selection import train_test_split 
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
len(X_train)
# Out:
# 394

# %%
len(X_test)
# Out:
# 99

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.6419162751312453

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
cv = ShuffleSplit(n_splits=5 , test_size=0.2 , random_state=0)
cross_val_score(LinearRegression(),X,y,cv=cv)
# Out:
# array([0.58503662, 0.63215592, 0.5418825 , 0.60630383, 0.68272275])
